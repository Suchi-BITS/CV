# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['q.jpg']))
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()
# Out:
#      <input type="file" id="files-6b46172a-7c69-4a48-9baf-c98703e65e98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b46172a-7c69-4a48-9baf-c98703e65e98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving q.jpg to q (2).jpg

# %%
# example of converting an image with the Keras API
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array 
from keras.preprocessing.image import array_to_img # load the image
 
print(type(im))
# convert to numpy array
img_array = img_to_array(im) 
print(img_array.dtype)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# float32

# %%
# convert to numpy array
img_array = img_to_array(im) 
print(img_array.dtype)
print(img_array.shape)
# convert back to image
img_pil = array_to_img(img_array) 
print(type(im))
# Out:
# float32
# (1440, 1440, 3)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
#control+m+bw
